# %%
from langgraph.graph import StateGraph, START, END
# from langchain_openai import ChatOpenAI
from langchain_groq import ChatGroq
from dotenv import load_dotenv
from typing import TypedDict, Annotated
from pydantic import BaseModel, Field
import operator

# %%
load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model='openai/gpt-oss-120b')

# %%
class EvaluationSchema(BaseModel):
    feedback: str = Field(description='Detailed feedbackfor the essay')
    score: float = Field(description='Score out of 10', ge=0, le=10)

# %%
structured_model = model.with_structured_output(EvaluationSchema)

# %%
essay = """India in the Age of AI
As the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.

India's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.

One of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.

However, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.

Another pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.

To harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.

India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.

In conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society."""

# %%
prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {essay}'
output = structured_model.invoke(prompt)

# %%
output.feedback
# Out:
# 'The essay is well‑organized and presents a clear, logical progression from introduction to conclusion. The author demonstrates a strong command of vocabulary (e.g., "transformative era," "socio‑economic and geopolitical future," "human‑centered development") and uses varied sentence structures that keep the prose engaging. The use of specific data ("over 5 million STEM graduates annually") and concrete examples (agriculture, healthcare, education, governance) adds credibility and depth.\n\nAreas for improvement:\n1. **Redundancy** – a few ideas are repeated (e.g., the notion of AI as an "enabler" appears multiple times) which could be streamlined.\n2. **Punctuation** – occasional missing commas in complex sentences (e.g., "India’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth" could benefit from a comma after "dividend").\n3. **Stylistic polish** – some phrases are slightly wordy (e.g., "the age of AI brings with it immense promise as well as unprecedented challenges"). Concise alternatives would improve readability.\n4. **Citation of sources** – while not strictly a language issue, referencing the "National AI Strategy (AI for All)" with a date or brief citation would strengthen authority.\n5. **Consistency** – the essay shifts between "AI" and "artificial intelligence"; maintaining one term or using the full form on first mention and the abbreviation thereafter would aid consistency.\n\nOverall, the essay demonstrates a high level of language proficiency, coherent argumentation, and effective use of rhetorical devices. Minor refinements in redundancy, punctuation, and conciseness would elevate it further.'

# %%
output.score
# Out:
# 8.5

# %%
class UPSCState(TypedDict):
    essay: str
    language_feedback: str
    analysis_feedback: str
    clarity_feedback: str
    overall_feedback: str
    individual_scores: Annotated[list[int], operator.add]
    avg_score: float

# %%
def evaluate_language(state: UPSCState):

    prompt = f'Evaluate the language quality of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'language_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_analysis(state: UPSCState):

    prompt = f'Evaluate the depth of analysis of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'analysis_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def evaluate_thought(state: UPSCState):

    prompt = f'Evaluate the clarity of thought of the following essay and provide a feedback and assign a score out of 10 \n {state["essay"]}'
    output = structured_model.invoke(prompt)

    return {'clarity_feedback': output.feedback, 'individual_scores': [output.score]}

# %%
def final_evaluation(state: UPSCState):

    # summary feedback
    prompt = f'Based on the following feedbacks create a summarized feedback \n language feedback - {state["language_feedback"]} \n depth of analysis feedback - {state["analysis_feedback"]} \n clarity of thought feedback - {state["clarity_feedback"]}'
    overall_feedback = model.invoke(prompt).content

    # avg calculate
    avg_score = sum(state['individual_scores'])/len(state['individual_scores'])

    return {'overall_feedback': overall_feedback, 'avg_score':  f"{avg_score:.2f}"}

# %%
graph = StateGraph(UPSCState)

graph.add_node('evaluate_language', evaluate_language)
graph.add_node('evaluate_analysis', evaluate_analysis)
graph.add_node('evaluate_thought', evaluate_thought)
graph.add_node('final_evaluation', final_evaluation)

# edges
graph.add_edge(START, 'evaluate_language')
graph.add_edge(START, 'evaluate_analysis')
graph.add_edge(START, 'evaluate_thought')

graph.add_edge('evaluate_language', 'final_evaluation')
graph.add_edge('evaluate_analysis', 'final_evaluation')
graph.add_edge('evaluate_thought', 'final_evaluation')

graph.add_edge('final_evaluation', END)

workflow = graph.compile()

# %%
workflow

# %%
essay2 = """India and AI Time

Now world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.

India have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.

In farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.

But problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.

One more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.

India must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.

If India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.

So, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India"."""

# %%
intial_state = {
    'essay': essay2
}

workflow.invoke(intial_state)
# Out:
# {'essay': 'India and AI Time\n\nNow world change very fast because new tech call Artificial Intel… something (AI). India also want become big in this AI thing. If work hard, India can go top. But if no careful, India go back.\n\nIndia have many good. We have smart student, many engine-ear, and good IT peoples. Big company like TCS, Infosys, Wipro already use AI. Government also do program “AI for All”. It want AI in farm, doctor place, school and transport.\n\nIn farm, AI help farmer know when to put seed, when rain come, how stop bug. In health, AI help doctor see sick early. In school, AI help student learn good. Government office use AI to find bad people and work fast.\n\nBut problem come also. First is many villager no have phone or internet. So AI not help them. Second, many people lose job because AI and machine do work. Poor people get more bad.\n\nOne more big problem is privacy. AI need big big data. Who take care? India still make data rule. If no strong rule, AI do bad.\n\nIndia must all people together – govern, school, company and normal people. We teach AI and make sure AI not bad. Also talk to other country and learn from them.\n\nIf India use AI good way, we become strong, help poor and make better life. But if only rich use AI, and poor no get, then big bad thing happen.\n\nSo, in short, AI time in India have many hope and many danger. We must go right road. AI must help all people, not only some. Then India grow big and world say "good job India".',
#  'language_feedback': 'The essay attempts to discuss the opportunities and challenges of AI in India, but the language quality is low. The writing contains many grammatical errors, awkward phrasing, and inconsistent verb tenses (e.g., "Now world change very fast because new tech call Artificial Intel… something (AI)" and "India also want become big in this AI thing"). Sentence structure is often fragmented, with missing articles and prepositions, making the meaning unclear at times. Vocabulary is limited and sometimes inaccurate (e.g., "engine-ear" instead of "engineer", "doctor place" for "hospital"). The essay lacks proper punctuation, capitalization, and cohesive flow between ideas. While the overall ideas are present, the execution hampers readability and professionalism. To improve, focus on correct grammar, clearer sentence construction, appropriate terminology, and better organization of paragraphs.\n\nOverall, the language quality is poor, reflecting a score of 3 out of 10.',
#  'analysis_feedback': 'The essay attempts to cover a broad range of topics related to AI in India—its potential benefits in agriculture, healthcare, education, and governance, as well as challenges such as digital divide, job displacement, and privacy. However, the analysis remains superficial. The arguments are presented in a list‑like fashion without supporting evidence, concrete examples, or nuanced discussion of trade‑offs. The essay lacks depth in several key areas:\n\n1. **Evidence and Data** – No statistics, case studies, or references to existing Indian AI initiatives are provided to substantiate claims about benefits or risks.\n2. **Critical Examination** – The piece mentions problems (e.g., lack of internet access, job loss, privacy) but does not explore underlying causes, scale, or possible mitigation strategies beyond vague calls for "strong rules" and "teaching AI."\n3. **Policy Insight** – The mention of "AI for All" and data‑rule gaps is not elaborated; there is no discussion of current policies (e.g., NITI Aayog’s AI strategy, Personal Data Protection Bill) or how they could be strengthened.\n4. **Stakeholder Perspective** – While the essay calls for collaboration among government, schools, companies, and citizens, it does not analyze the differing incentives, capacities, or potential conflicts among these groups.\n5. **Structure and Cohesion** – The essay jumps between ideas without clear logical flow, making it difficult to see how each point builds a coherent argument.\n6. **Depth of Vision** – The concluding optimism is not backed by a strategic roadmap; there is no discussion of required investments, talent pipelines, or international cooperation beyond a generic statement.\n\nOverall, the essay demonstrates awareness of the major themes surrounding AI in India but fails to provide an in‑depth, evidence‑based analysis. To improve, the writer should incorporate data, specific examples, a more systematic evaluation of pros and cons, and concrete policy recommendations.\n\n**Score (out of 10):** 4.5',
#  'clarity_feedback': 'The essay conveys a clear overall message – that AI presents both opportunities and challenges for India and that the country must manage its adoption carefully – but the expression of those ideas is hindered by numerous language and organizational problems. \n\n**Strengths**\n- The writer identifies several concrete domains (agriculture, health, education, governance) where AI could be beneficial.\n- The essay also mentions realistic risks such as the digital divide, job displacement, and privacy concerns.\n- There is a call for inclusive policy‑making and collaboration among government, industry, academia, and citizens.\n\n**Areas for improvement**\n1. **Structure and flow** – The piece jumps from one point to another without clear transitions or paragraph breaks. A more logical order (e.g., introduction, benefits, risks, solutions, conclusion) would help readers follow the argument.\n2. **Clarity of language** – Frequent grammatical errors, misspellings (e.g., "engine‑ear", "doctor place"), and fragmented sentences make the ideas hard to parse. Proofreading or using simpler sentence constructions would improve readability.\n3. **Specificity** – The essay mentions programs like “AI for All” and companies using AI but provides no concrete examples or data to support the claims. Adding specific initiatives or statistics would strengthen the argument.\n4. **Consistency of terminology** – The term "AI" is introduced as "Artificial Intel… something" which is confusing. Define the term once and use it consistently.\n5. **Depth of analysis** – The discussion of risks is brief. Expanding on how job loss could be mitigated (e.g., reskilling programs) or what privacy regulations are needed would show deeper critical thinking.\n\nOverall, the essay demonstrates an understanding of the topic but lacks the precision, organization, and linguistic accuracy expected for a clear, persuasive piece.\n\n**Score (out of 10)**: 4',
#  'overall_feedback': '**Summarized Feedback**\n\n| Dimension | Main Issues | Strengths | Suggested Improvements | Score (out of 10) |\n|-----------|-------------|-----------|------------------------|-------------------|\n| **Language** | • Frequent grammatical errors, awkward phrasing, inconsistent verb tenses.<br>• Fragmented sentences, missing articles/prepositions, poor punctuation and capitalization.<br>• Limited and sometimes inaccurate vocabulary (e.g., “engine‑ear”, “doctor place”). | • The core ideas are recognizable. | • Proof‑read for grammar, spelling, and punctuation.<br>• Use standard terminology (“Artificial Intelligence”, “engineer”, “hospital”).<br>• Build complete sentences and vary sentence structures.<br>• Organise paragraphs with clear topic sentences. | **3** |\n| **Depth of Analysis** | • Arguments are superficial; presented as a list without evidence.<br>• No statistics, case studies, or references to existing Indian AI initiatives.<br>• Lacks critical examination of causes, scale, or mitigation strategies for risks.<br>• No detailed discussion of current policies (e.g., NITI Aayog’s AI strategy, Personal Data Protection Bill).<br>• Stakeholder incentives and possible conflicts are not explored.<br>• Structure is disjointed, preventing a coherent argument. | • Identifies major benefit areas (agriculture, health, education, governance) and key risks (digital divide, job loss, privacy). | • Incorporate data, examples, and citations to substantiate claims.<br>• Analyse root causes of challenges and propose concrete solutions (e.g., reskilling programmes, privacy frameworks).<br>• Discuss existing policies and suggest realistic enhancements.<br>• Present a logical flow: benefits → risks → policy response → roadmap. | **4.5** |\n| **Clarity of Thought** | • Overall message (AI offers opportunities & challenges for India) is clear, but expression is muddled by language and organization.<br>• Abrupt jumps between points; missing transitions.<br>• Inconsistent terminology (“Artificial Intel…”) confuses readers.<br>• Lack of specific examples weakens persuasiveness. | • Recognises the need for inclusive policymaking and multi‑stakeholder collaboration. | • Re‑structure the essay (intro → benefits → risks → solutions → conclusion).<br>• Use clear, consistent terminology; define “AI” once and stick to it.<br>• Add concrete examples (e.g., AI‑driven crop‑monitoring pilots, AI‑enabled tele‑diagnosis projects).<br>• Employ simple, precise sentences to improve readability. | **4** |\n\n### Overall Assessment\nThe essay shows awareness of the key themes surrounding AI in India, but poor language mechanics, shallow analysis, and weak organization hinder its impact. Raising the score will require:\n\n1. **Language polish** – rigorous proofreading and use of standard academic English.  \n2. **Evidence‑driven analysis** – embed statistics, case studies, and policy references.  \n3. **Logical structure** – clear sections with smooth transitions and a strategic conclusion outlining actionable steps.\n\n**Combined average score:** **3.8 / 10**. With focused revisions in the three areas above, the essay can become a compelling, professional discussion of AI’s promise and challenges for India.',
#  'individual_scores': [4.5, 3.0, 4.0],
#  'avg_score': '3.83'}

# %%
intial_state = {
    'essay': essay
}

workflow.invoke(intial_state)
# Out:
# {'essay': "India in the Age of AI\nAs the world enters a transformative era defined by artificial intelligence (AI), India stands at a critical juncture — one where it can either emerge as a global leader in AI innovation or risk falling behind in the technology race. The age of AI brings with it immense promise as well as unprecedented challenges, and how India navigates this landscape will shape its socio-economic and geopolitical future.\n\nIndia's strengths in the AI domain are rooted in its vast pool of skilled engineers, a thriving IT industry, and a growing startup ecosystem. With over 5 million STEM graduates annually and a burgeoning base of AI researchers, India possesses the intellectual capital required to build cutting-edge AI systems. Institutions like IITs, IIITs, and IISc have begun fostering AI research, while private players such as TCS, Infosys, and Wipro are integrating AI into their global services. In 2020, the government launched the National AI Strategy (AI for All) with a focus on inclusive growth, aiming to leverage AI in healthcare, agriculture, education, and smart mobility.\n\nOne of the most promising applications of AI in India lies in agriculture, where predictive analytics can guide farmers on optimal sowing times, weather forecasts, and pest control. In healthcare, AI-powered diagnostics can help address India’s doctor-patient ratio crisis, particularly in rural areas. Educational platforms are increasingly using AI to personalize learning paths, while smart governance tools are helping improve public service delivery and fraud detection.\n\nHowever, the path to AI-led growth is riddled with challenges. Chief among them is the digital divide. While metropolitan cities may embrace AI-driven solutions, rural India continues to struggle with basic internet access and digital literacy. The risk of job displacement due to automation also looms large, especially for low-skilled workers. Without effective skilling and re-skilling programs, AI could exacerbate existing socio-economic inequalities.\n\nAnother pressing concern is data privacy and ethics. As AI systems rely heavily on vast datasets, ensuring that personal data is used transparently and responsibly becomes vital. India is still shaping its data protection laws, and in the absence of a strong regulatory framework, AI systems may risk misuse or bias.\n\nTo harness AI responsibly, India must adopt a multi-stakeholder approach involving the government, academia, industry, and civil society. Policies should promote open datasets, encourage responsible innovation, and ensure ethical AI practices. There is also a need for international collaboration, particularly with countries leading in AI research, to gain strategic advantage and ensure interoperability in global systems.\n\nIndia’s demographic dividend, when paired with responsible AI adoption, can unlock massive economic growth, improve governance, and uplift marginalized communities. But this vision will only materialize if AI is seen not merely as a tool for automation, but as an enabler of human-centered development.\n\nIn conclusion, India in the age of AI is a story in the making — one of opportunity, responsibility, and transformation. The decisions we make today will not just determine India’s AI trajectory, but also its future as an inclusive, equitable, and innovation-driven society.",
#  'language_feedback': 'The essay is well‑structured and presents a clear, logical progression from introduction to conclusion. The author uses varied sentence structures and appropriate academic tone, which makes the piece engaging and authoritative. Vocabulary is generally precise (e.g., “transformative era,” “demographic dividend,” “human‑centered development”), and key concepts are explained succinctly. Transitions between paragraphs are smooth, and the use of concrete examples (agriculture, healthcare, education) reinforces the arguments.\n\nAreas for improvement:\n1. **Repetition** – Certain phrases such as “AI‑led growth” and “responsible AI” appear multiple times; varying the wording would keep the prose fresher.\n2. **Minor grammatical slips** – A few articles are missing or misplaced (e.g., “the risk of job displacement… also looms large” could be “the risk of job displacement also looms large”), and “AI for All” should be italicised or quoted for consistency.\n3. **Citation of data** – Numbers like “over 5 million STEM graduates annually” would be stronger with a brief source reference or qualifier (e.g., “approximately”).\n4. **Paragraph length** – Some paragraphs are dense; breaking the longer ones into shorter blocks would improve readability.\n5. **Stylistic nuance** – The conclusion repeats the phrase “in the age of AI” which feels redundant; a more varied closing sentence would leave a stronger impact.\n\nOverall, the language is articulate, cohesive, and appropriate for an analytical essay on policy and technology. With minor polishing, it would reach a near‑professional level.\n\nScore: 8.5/10',
#  'analysis_feedback': 'The essay provides a solid overview of India’s AI landscape, highlighting key strengths (large talent pool, vibrant IT sector, government strategy) and promising application domains (agriculture, healthcare, education, governance). It also acknowledges major challenges such as the digital divide, job displacement, and data‑privacy concerns, and it calls for a multi‑stakeholder, ethically‑grounded policy approach. However, the analysis remains at a relatively high level. It lacks concrete data (e.g., specific investment figures, adoption rates, or comparative benchmarks with other countries), detailed case studies that illustrate successes or failures, and a deeper examination of policy mechanisms (e.g., how AI‑for‑All will be funded, specific skilling programmes, or regulatory timelines). The discussion of international collaboration is generic, and there is little exploration of potential geopolitical implications or the role of public‑private partnerships in scaling solutions. To reach a higher depth, the essay would benefit from more granular evidence, nuanced trade‑off analysis, and actionable recommendations.\n\nOverall, the piece is well‑structured and covers the essential themes, but its analytical depth is moderate rather than exhaustive.',
#  'clarity_feedback': 'The essay presents a clear, well‑structured argument about India’s position in the AI era. It begins with a strong introductory thesis, outlines India’s strengths (human capital, institutions, industry), gives concrete examples of promising AI applications (agriculture, healthcare, education, governance), and then systematically addresses the major challenges (digital divide, job displacement, data privacy). The discussion of solutions – multi‑stakeholder governance, open data, ethical frameworks, and international collaboration – follows logically from the problem identification, reinforcing the central claim that AI must be harnessed responsibly to drive inclusive growth. Transitions between paragraphs are smooth, and the conclusion neatly ties back to the opening premise. Minor issues include occasional repetition (e.g., “AI‑led growth” vs. “AI‑driven solutions”) and a lack of specific policy recommendations, but overall the essay maintains a coherent line of thought throughout.\n\nScore: 8.5 out of 10',
#  'overall_feedback': '**Summarized Feedback**\n\n**Strengths**  \n- **Structure & Cohesion:** The essay follows a logical flow from introduction to conclusion, with smooth paragraph transitions that keep the argument easy to follow.  \n- **Academic Tone & Vocabulary:** Varied sentence structures, precise terminology (“transformative era,” “demographic dividend”) and an authoritative voice make the piece engaging.  \n- **Clarity of Thought:** The central claim—that AI must be harnessed responsibly for inclusive growth—is consistently supported by clear examples (agriculture, healthcare, education, governance) and a logical problem‑solution framework.  \n- **Use of Examples:** Concrete sectoral illustrations reinforce the arguments and demonstrate a good grasp of the topic.\n\n**Areas for Improvement**  \n\n| Aspect | What to Address | Suggested Action |\n|--------|----------------|-----------------|\n| **Repetition** | Frequent reuse of phrases such as “AI‑led growth,” “responsible AI,” and “in the age of AI.” | Vary wording or use synonyms; rotate phrasing in the conclusion. |\n| **Grammar & Formatting** | Minor article errors; inconsistent styling of titles (e.g., *AI for All*). | Proof‑read for article placement; italicise or quote program names consistently. |\n| **Citation & Data Precision** | Numbers (e.g., “over 5\u202fmillion STEM graduates annually”) lack sources or qualifiers. | Add brief citations or qualifiers like “approximately” or “according to\u202f[source]”. |\n| **Paragraph Length** | Some paragraphs are dense, reducing readability. | Break long blocks into shorter paragraphs or use bullet points for lists. |\n| **Depth of Analysis** | High‑level overview; missing concrete data (investment figures, adoption rates), detailed case studies, and specific policy mechanisms. | Incorporate quantitative benchmarks, short case studies, and explicit recommendations (e.g., funding models for “AI‑for‑All,” timeline for regulatory rollout). |\n| **International & Geopolitical Context** | Discussion of collaboration is generic; limited exploration of geopolitical implications and PPP roles. | Provide specific examples of cross‑border projects, outline potential geopolitical risks, and detail public‑private partnership structures. |\n| **Stylistic Nuance** | Redundant phrasing in the conclusion (“in the age of AI”). | Re‑craft the closing sentence with a fresh expression that still echoes the thesis. |\n\n**Overall Assessment**  \n- **Language Quality:** 8.5\u202f/\u202f10 – articulate and professional, needing only minor polishing.  \n- **Clarity of Thought:** 8.5\u202f/\u202f10 – well‑structured and logically coherent, with only slight repetition.  \n- **Analytical Depth:** 7\u202f/\u202f10 – solid overview but limited by lack of granular evidence and actionable policy detail.\n\n**Combined Score (average): ≈\u202f8\u202f/\u202f10**\n\n**Bottom‑Line Recommendation**  \nThe essay is already strong in organization, tone, and overall argumentation. Elevating it to a near‑professional level will mainly require:\n\n1. **Enriching the analysis** with specific data, case studies, and concrete policy recommendations.  \n2. **Fine‑tuning language** to eliminate repetition, correct minor grammatical slips, and ensure consistent formatting.  \n3. **Improving readability** by shortening overly long paragraphs and varying concluding phrasing.\n\nAddressing these points will transform a solid analytical piece into a compelling, evidence‑driven policy brief on India’s AI future.',
#  'individual_scores': [7.5, 8.5, 8.5],
#  'avg_score': '8.17'}
